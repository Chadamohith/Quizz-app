# %% [markdown]
# <a href="https://colab.research.google.com/github/Chadamohith/Quizz-app/blob/main/Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# quiz.py
score = 0

q1 = input("Capital of India? ")
if q1.lower() == "delhi":
    score += 1

q2 = input("5 + 3 = ? ")
if q2 == "8":
    score += 1

print("Score:", score)
# Out:
# Capital of India? Delhi
# 5 + 3 = ? 8
# Score: 2
